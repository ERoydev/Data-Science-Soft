# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pew = pd.read_csv("data/pew.csv")

# %%
# Here i see only 3 variables(columns) that this dataset should have
# religion, count, salary_range

pew
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
pew.describe().T
# Out:
#                     count        mean         std  min    25%   50%     75%  \
# <$10k                18.0  107.222222  168.931784  1.0  12.25  20.0  170.00
# $10-20k              18.0  154.500000  255.172433  2.0  14.75  27.0  193.00
# $20-30k              18.0  186.500000  309.891869  3.0  17.00  33.5  192.00
# $30-40k              18.0  183.444444  291.470354  4.0  15.75  40.0  198.75
# $40-50k              18.0  171.388889  271.144446  2.0  15.00  34.0  166.75
# $50-75k              18.0  288.055556  458.442436  7.0  34.25  66.5  201.50
# $75-100k             18.0  221.666667  345.078849  3.0  25.25  65.5  128.75
# $100-150k            18.0  177.611111  275.679724  4.0  22.50  48.5  103.50
# >150k                18.0  144.888889  205.224952  4.0  23.75  53.5  134.25
# Don't know/refused   18.0  340.055556  530.523878  8.0  41.25  74.5  294.75
#
#                        max
# <$10k                575.0
# $10-20k              869.0
# $20-30k             1064.0
# ...

# %%
pew_tidy = pew.melt(id_vars=["religion"], var_name="income", value_name="frequency")
pew_tidy
# Out:
#                   religion              income  frequency
# 0                 Agnostic               <$10k         27
# 1                  Atheist               <$10k         12
# 2                 Buddhist               <$10k         27
# 3                 Catholic               <$10k        418
# 4       Don’t know/refused               <$10k         15
# ..                     ...                 ...        ...
# 175               Orthodox  Don't know/refused         73
# 176        Other Christian  Don't know/refused         18
# 177           Other Faiths  Don't know/refused         71
# 178  Other World Religions  Don't know/refused          8
# 179           Unaffiliated  Don't know/refused        597
#
# [180 rows x 3 columns]

# %%
pew_tidy.dtypes
# Out:
# religion     object
# income       object
# frequency     int64
# dtype: object

# %%
pew_tidy.religion = pew_tidy.religion.astype("category")

# %%
pew_tidy.memory_usage()
# Out:
# Index         132
# religion      880
# income       1440
# frequency    1440
# dtype: int64

# %%
#### NEXT EXERCISE ################################################
#### NEXT EXERCISE ################################################
#### NEXT EXERCISE ################################################
#### NEXT EXERCISE ################################################
#### NEXT EXERCISE ################################################
#### NEXT EXERCISE ################################################

# %%
# Dataset tubercolosis reasearch
tb = pd.read_csv("data/tb.csv")
tb
# Out:
#      iso2  year  m04   m514   m014  m1524   m2534   m3544   m4554  m5564  ...  \
# 0      AD  1989  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# 1      AD  1990  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# 2      AD  1991  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# 3      AD  1992  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# 4      AD  1993  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# ...   ...   ...  ...    ...    ...    ...     ...     ...     ...    ...  ...
# 5764   ZW  2004  NaN    NaN  187.0  833.0  2908.0  2298.0  1056.0  366.0  ...
# 5765   ZW  2005  NaN    NaN  210.0  837.0  2264.0  1855.0   762.0  295.0  ...
# 5766   ZW  2006  NaN    NaN  215.0  736.0  2391.0  1939.0   896.0  348.0  ...
# 5767   ZW  2007  6.0  132.0  138.0  500.0  3693.0     0.0   716.0  292.0  ...
# 5768   ZW  2008  NaN    NaN  127.0  614.0     0.0  3316.0   704.0  263.0  ...
#
# ...

# %%
tb.shape
# Out:
# (5769, 22)

# %%
tb.dtypes
# Out:
# iso2      object
# year       int64
# m04      float64
# m514     float64
# m014     float64
# m1524    float64
# m2534    float64
# m3544    float64
# m4554    float64
# m5564    float64
# m65      float64
# mu       float64
# f04      float64
# f514     float64
# f014     float64
# f1524    float64
# f2534    float64
# f3544    float64
# f4554    float64
# f5564    float64
# f65      float64
# fu       float64
# dtype: object

# %%
tb[(tb.year == 1989) & (tb.iso2 == "AD")].values
# Out:
# array([['AD', 1989, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]], dtype=object)

# %%
tb.describe().T
# Out:
#         count         mean          std     min     25%     50%      75%  \
# year   5769.0  1994.229329     8.423265  1980.0  1987.0  1994.0  2002.00
# m04     392.0     8.806122    46.094789     0.0     0.0     0.0     2.00
# m514    401.0    28.975062   127.881505     0.0     0.0     1.0     8.00
# m014   2381.0    79.438051   280.489536     0.0     0.0     6.0    36.00
# m1524  2407.0   922.364769  4278.638975     0.0    10.0    92.0   511.50
# m2534  2408.0  1301.894518  5253.398971     0.0    15.0   151.5   728.00
# m3544  2415.0  1205.566046  5409.064589     0.0    16.0   134.0   591.50
# m4554  2421.0   983.515489  4780.782748     0.0    13.0    98.0   434.00
# m5564  2414.0   696.171914  3771.934518     0.0     9.0    62.0   273.75
# m65    2408.0   609.440615  3660.224592     0.0     8.0    53.0   227.25
# mu      273.0     5.710623    85.713531     0.0     0.0     0.0     0.00
# f04     393.0     6.417303    39.630100     0.0     0.0     0.0     1.00
# ...

# %%
tb_tidy = tb.melt(id_vars=["iso2", "year"], var_name = "sex_and_age", value_name = "cases")

# %%
tb_tidy["gender"] = tb_tidy.sex_and_age.str.slice(0, 1)

# %%
tb_tidy["age_group"] = tb_tidy.sex_and_age.str.slice(1)

# %%
tb_tidy = tb_tidy.drop(columns = ["sex_and_age"])

# %%
tb_tidy.describe().T
# Out:
#           count         mean          std     min     25%     50%     75%  \
# year   115380.0  1994.229329     8.422571  1980.0  1987.0  1994.0  2002.0
# cases   35750.0   609.378881  3278.187960     0.0     4.0    36.0   245.0
#
#            max
# year    2008.0
# cases  90498.0

# %%
tb_tidy_no_missing = tb_tidy.dropna()

# %%
tb_tidy_no_missing.cases.mean()
# Out:
# 611.1249437443745

# %%
tb_tidy_no_missing.age_group.str.len().value_counts()
# Out:
# age_group
# 4    23912
# 2     5561
# 3     5536
# 1      543
# Name: count, dtype: int64

# %%
tb_tidy_no_missing.age_group.unique()
# Out:
# array(['04', '514', '014', '1524', '2534', '3544', '4554', '5564', '65',
#        'u'], dtype=object)

# %%
def process_age_group(age_group):
    ages = {"04": "0-4", "65": "65+", "u": "unknown"}
    if age_group in ages:
        return ages[age_group]
    return f"{age_group[:-2]} - {age_group[-2:]}"

# %%
tb_tidy_no_missing.age_group = tb_tidy_no_missing.age_group.apply(process_age_group)
# Out:
# C:\Users\eroyd\AppData\Local\Temp\ipykernel_27572\690891332.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tb_tidy_no_missing.age_group = tb_tidy_no_missing.age_group.apply(process_age_group)

# %%
# THE FINAL CLEANED TIDY DATA
tb_tidy_no_missing
# Out:
#        iso2  year  cases gender age_group
# 15       AD  2005    0.0      m       0-4
# 16       AD  2006    0.0      m       0-4
# 18       AD  2008    0.0      m       0-4
# 42       AE  2006    0.0      m       0-4
# 43       AE  2007    0.0      m       0-4
# ...     ...   ...    ...    ...       ...
# 115195   VU  2008    0.0      f   unknown
# 115269   YE  2008    0.0      f   unknown
# 115323   ZA  2008    0.0      f   unknown
# 115350   ZM  2008    0.0      f   unknown
# 115379   ZW  2008    0.0      f   unknown
#
# [35552 rows x 5 columns]

# %%
tb_tidy_no_missing.age_group.unique()
# Out:
# array(['0-4', '5 - 14', '0 - 14', '15 - 24', '25 - 34', '35 - 44',
#        '45 - 54', '55 - 64', '65+', 'unknown'], dtype=object)

# %%
tb_tidy_no_missing.gender = tb_tidy_no_missing.gender.astype("category")
tb_tidy_no_missing.age_group = tb_tidy_no_missing.age_group.astype("category")
# Out:
# C:\Users\eroyd\AppData\Local\Temp\ipykernel_27572\1670776853.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tb_tidy_no_missing.gender = tb_tidy_no_missing.gender.astype("category")
# C:\Users\eroyd\AppData\Local\Temp\ipykernel_27572\1670776853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tb_tidy_no_missing.age_group = tb_tidy_no_missing.age_group.astype("category")

# %%
tb_tidy_no_missing = tb_tidy_no_missing[["iso2", "year", "gender", "age_group", "cases"]]

# %%
tb_tidy_no_missing.cases = tb_tidy_no_missing.cases.astype(int)

# %%
tb_tidy_no_missing = tb_tidy_no_missing.sort_values(["iso2", "year"])

# %%
tb_tidy_no_missing = tb_tidy_no_missing.reset_index(drop = True)

# %%
tb_tidy_no_missing
# Out:
#       iso2  year gender   age_group  cases
# 0       AD  1996      m   01 - -  4      0
# 1       AD  1996      m  15 -  - 24      0
# 2       AD  1996      m  25 -  - 34      0
# 3       AD  1996      m  35 -  - 44      4
# 4       AD  1996      m  45 -  - 54      1
# ...    ...   ...    ...         ...    ...
# 35547   ZW  2008      f  35 -  - 44   2890
# 35548   ZW  2008      f  45 -  - 54    467
# 35549   ZW  2008      f  55 -  - 64    174
# 35550   ZW  2008      f      6 - 5+    105
# 35551   ZW  2008      f  unkno - wn      0
#
# [35552 rows x 5 columns]
